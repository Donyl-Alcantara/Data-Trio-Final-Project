# %%
from functools import reduce
import pandas as pd
import os

# %%
files = {
    "usd_php":    "../data/semi-cleaned/fx_usd_php.parquet",
    "rub_usd":    "../data/semi-cleaned/fx_rub_usd.parquet",
    "brent":      "../data/semi-cleaned/brent_weekly.parquet",
    "wti":        "../data/semi-cleaned/wti_weekly.parquet",
    "dubai":      "../data/semi-cleaned/dubai_crude_weekly.parquet",
    "mops_gasoil":"../data/semi-cleaned/mops_gasoil_weekly.parquet",
    "mops_rbob":  "../data/semi-cleaned/mops_rbob_weekly.parquet",
    "cpi":        "../data/semi-cleaned/full_cpi.parquet",
}

# %%
for feature, path in files.items():
    df = pd.read_parquet(path)
    print(f"{feature}")
    print(f"index name: {df.index.name}")
    print(f"index dtype: {df.index.dtype}")
    print(f"date range: {df.index.min()} -> {df.index.max()}")
    print(f"shape: {df.shape}")
    print(f"columns: {list(df.columns)}")
    print(f"nulls: {df.isnull().sum().to_dict()}")
    print()
# Out:
# usd_php
# index name: week_monday
# index dtype: datetime64[ns]
# date range: 2015-01-05 00:00:00 -> 2026-05-11 00:00:00
# shape: (593, 2)
# columns: ['usd_php_close', 'usd_php_mean']
# nulls: {'usd_php_close': 0, 'usd_php_mean': 0}
#
# rub_usd
# index name: week_monday
# index dtype: datetime64[ns]
# date range: 2015-01-05 00:00:00 -> 2026-05-11 00:00:00
# shape: (593, 2)
# columns: ['rub_usd_close', 'rub_usd_mean']
# nulls: {'rub_usd_close': 0, 'rub_usd_mean': 0}
#
# brent
# index name: week_monday
# index dtype: datetime64[ns]
# date range: 2017-01-09 00:00:00 -> 2026-05-04 00:00:00
# shape: (487, 2)
# columns: ['brent_close', 'brent_mean']
# nulls: {'brent_close': 0, 'brent_mean': 0}
#
# wti
# index name: week_monday
# index dtype: datetime64[ns]
# date range: 2017-01-09 00:00:00 -> 2026-05-04 00:00:00
# shape: (487, 2)
# columns: ['wti_close', 'wti_mean']
# nulls: {'wti_close': 0, 'wti_mean': 0}
#
# dubai
# index name: week_monday
# index dtype: datetime64[ns]
# date range: 2017-01-09 00:00:00 -> 2026-05-11 00:00:00
# shape: (488, 1)
# columns: ['dubai_close']
# nulls: {'dubai_close': 0}
#
# mops_gasoil
# index name: week_monday
# index dtype: datetime64[ns]
# date range: 2015-01-05 00:00:00 -> 2026-05-04 00:00:00
# shape: (592, 2)
# columns: ['mops_gasoil_close', 'mops_gasoil_mean']
# nulls: {'mops_gasoil_close': 0, 'mops_gasoil_mean': 0}
#
# mops_rbob
# index name: week_monday
# index dtype: datetime64[ns]
# date range: 2015-01-05 00:00:00 -> 2026-05-11 00:00:00
# shape: (593, 2)
# columns: ['mops_rbob_close', 'mops_rbob_mean']
# nulls: {'mops_rbob_close': 0, 'mops_rbob_mean': 0}
#
# cpi
# index name: week_monday
# index dtype: datetime64[ns]
# date range: 2015-01-05 00:00:00 -> 2026-05-11 00:00:00
# shape: (593, 1)
# columns: ['cpi_value']
# nulls: {'cpi_value': 0}

# %%
# join everything
dfs = [
    pd.read_parquet("../data/semi-cleaned/fx_usd_php.parquet"),
    pd.read_parquet("../data/semi-cleaned/brent_weekly.parquet"),
    pd.read_parquet("../data/semi-cleaned/wti_weekly.parquet"),
    pd.read_parquet("../data/semi-cleaned/mops_gasoil_weekly.parquet"),
    pd.read_parquet("../data/semi-cleaned/mops_rbob_weekly.parquet"),
    pd.read_parquet("../data/semi-cleaned/dubai_crude_weekly.parquet"),
    pd.read_parquet("../data/semi-cleaned/full_cpi.parquet"),
    pd.read_parquet("../data/semi-cleaned/fx_rub_usd.parquet"),
]

features = reduce(lambda l, r: l.join(r, how="outer"), dfs)
features = features.loc["2018-01-01":]

# %%
features
# Out:
#              usd_php_close  usd_php_mean  brent_close  brent_mean  wti_close  \
# week_monday
# 2018-01-01       49.750000     49.837600        66.73      66.520      60.46
# 2018-01-08       49.751999     49.859200        68.01      67.810      61.49
# 2018-01-15       50.248001     50.112200        69.64      69.470      64.22
# 2018-01-22       50.679001     50.474200        68.56      69.388      63.38
# 2018-01-29       50.724998     50.813000        70.08      70.040      66.27
# ...                    ...           ...          ...         ...        ...
# 2026-04-13       59.648998     59.842799       119.07     124.605      98.34
# 2026-04-20       59.988998     59.952801        98.63     114.432      85.91
# 2026-04-27       60.445999     60.025600       111.86     109.618      98.42
# 2026-05-04       61.313000     61.098600       113.89     113.890      99.89
# 2026-05-11       61.174999     61.174999          NaN         NaN        NaN
#
#              wti_mean  mops_gasoil_close  mops_gasoil_mean  mops_rbob_close  \
# week_monday
# 2018-01-01    59.8800          75.310997         75.340498        75.566402
# 2018-01-08    61.3625          80.377998         80.141001        75.003599
# 2018-01-15    63.2560          81.240997         80.935800        77.678998
# 2018-01-22    63.7700          81.219002         81.468500        78.271201
# 2018-01-29    65.1380          82.005997         81.789400        81.383401
# ...               ...                ...               ...              ...
# 2026-04-13   104.5440         194.065994        209.639999       127.566605
# 2026-04-20    93.8400         182.509003        191.773001       126.201603
# 2026-04-27    95.4300         195.337006        192.018002       145.429200
# 2026-05-04    99.8900         160.671005        188.504199       150.998403
# 2026-05-11        NaN                NaN               NaN       156.189603
#
#              mops_rbob_mean  dubai_close   cpi_value  rub_usd_close  \
# week_monday
# 2018-01-01        75.288150    61.384286   96.348116       0.017370
# 2018-01-08        75.106500    66.024783   97.200000       0.017552
# 2018-01-15        76.836480    66.024783   97.200000       0.017698
# 2018-01-22        78.160950    66.024783   97.200000       0.017701
# 2018-01-29        80.289720    66.024783   97.200000       0.017895
# ...                     ...          ...         ...            ...
# 2026-04-13       131.521320   126.706364  127.200000       0.012883
# 2026-04-20       129.302881   126.706364  127.200000       0.013094
# 2026-04-27       139.517280   126.706364  127.200000       0.013180
# 2026-05-04       152.537282   126.706364  127.200000       0.013341
# 2026-05-11       156.189603   126.706364  127.200000       0.013338
#
#              rub_usd_mean
# week_monday
# 2018-01-01       0.017285
# 2018-01-08       0.017434
# 2018-01-15       0.017577
# 2018-01-22       0.017689
# 2018-01-29       0.017765
# ...                   ...
# 2026-04-13       0.012655
# 2026-04-20       0.013160
# 2026-04-27       0.013279
# 2026-05-04       0.013354
# 2026-05-11       0.013338
#
# [437 rows x 14 columns]

# %%
features.corr()
# Out:
#                    usd_php_close  usd_php_mean  brent_close  brent_mean  \
# usd_php_close           1.000000      0.998037     0.469028    0.472167
# usd_php_mean            0.998037      1.000000     0.465741    0.469456
# brent_close             0.469028      0.465741     1.000000    0.993627
# brent_mean              0.472167      0.469456     0.993627    1.000000
# wti_close               0.452794      0.448965     0.988567    0.981429
# wti_mean                0.459356      0.455727     0.984751    0.988717
# mops_gasoil_close       0.561828      0.556440     0.936722    0.935830
# mops_gasoil_mean        0.566289      0.561476     0.932984    0.938220
# mops_rbob_close         0.435602      0.430867     0.949913    0.943564
# mops_rbob_mean          0.444470      0.440151     0.948817    0.950275
# dubai_close             0.542458      0.537959     0.967306    0.965101
# cpi_value               0.811547      0.811900     0.411278    0.409976
# rub_usd_close          -0.415588     -0.416036    -0.107090   -0.098473
# rub_usd_mean           -0.305692     -0.303285    -0.093788   -0.081220
#
#                    wti_close  wti_mean  mops_gasoil_close  mops_gasoil_mean  \
# usd_php_close       0.452794  0.459356           0.561828          0.566289
# usd_php_mean        0.448965  0.455727           0.556440          0.561476
# brent_close         0.988567  0.984751           0.936722          0.932984
# brent_mean          0.981429  0.988717           0.935830          0.938220
# wti_close           1.000000  0.993201           0.911029          0.905833
# wti_mean            0.993201  1.000000           0.908930          0.910126
# mops_gasoil_close   0.911029  0.908930           1.000000          0.995134
# mops_gasoil_mean    0.905833  0.910126           0.995134          1.000000
# mops_rbob_close     0.960024  0.954048           0.891939          0.889348
# mops_rbob_mean      0.958489  0.960503           0.892958          0.894931
# dubai_close         0.954597  0.951823           0.950314          0.947217
# cpi_value           0.442049  0.443681           0.443885          0.445217
# rub_usd_close      -0.151049 -0.144392          -0.054290         -0.050424
# rub_usd_mean       -0.127347 -0.117249          -0.035950         -0.033585
#
#                    mops_rbob_close  mops_rbob_mean  dubai_close  cpi_value  \
# usd_php_close             0.435602        0.444470     0.542458   0.811547
# usd_php_mean              0.430867        0.440151     0.537959   0.811900
# brent_close               0.949913        0.948817     0.967306   0.411278
# brent_mean                0.943564        0.950275     0.965101   0.409976
# wti_close                 0.960024        0.958489     0.954597   0.442049
# wti_mean                  0.954048        0.960503     0.951823   0.443681
# mops_gasoil_close         0.891939        0.892958     0.950314   0.443885
# mops_gasoil_mean          0.889348        0.894931     0.947217   0.445217
# mops_rbob_close           1.000000        0.995564     0.924907   0.441842
# mops_rbob_mean            0.995564        1.000000     0.925007   0.448575
# dubai_close               0.924907        0.925007     1.000000   0.473361
# cpi_value                 0.441842        0.448575     0.473361   1.000000
# rub_usd_close            -0.122634       -0.120641    -0.173380  -0.719087
# rub_usd_mean             -0.082535       -0.079895    -0.129476  -0.525184
#
#                    rub_usd_close  rub_usd_mean
# usd_php_close          -0.415588     -0.305692
# usd_php_mean           -0.416036     -0.303285
# brent_close            -0.107090     -0.093788
# brent_mean             -0.098473     -0.081220
# wti_close              -0.151049     -0.127347
# wti_mean               -0.144392     -0.117249
# mops_gasoil_close      -0.054290     -0.035950
# mops_gasoil_mean       -0.050424     -0.033585
# mops_rbob_close        -0.122634     -0.082535
# mops_rbob_mean         -0.120641     -0.079895
# dubai_close            -0.173380     -0.129476
# cpi_value              -0.719087     -0.525184
# rub_usd_close           1.000000      0.747250
# rub_usd_mean            0.747250      1.000000

# %%
doe = pd.read_parquet("../data/semi-cleaned/processed_doe_data.parquet")

# 1. Parse the date
doe["effectivity_date"] = pd.to_datetime(doe["Effectivity Date"], errors="coerce")
doe = doe.dropna(subset=["effectivity_date"])

# 2. Standardize product names (you have 'Ron95', 'RON 95' etc.)
doe["product"] = doe["Product"].str.upper().str.replace(" ", "").str.replace("-", "")
product_map = {
    "RON91": "ron91", "RON95": "ron95", "RON97": "ron97", "RON100": "ron100",
    "DIESEL": "diesel", "DIESELPLUS": "diesel_plus", "KEROSENE": "kerosene"
}
doe["product"] = doe["product"].map(product_map)
doe = doe.dropna(subset=["product"])

# 3. Compute mid price
doe["price_mid"] = (doe["Price Low (P/L)"] + doe["Price High (P/L)"]) / 2

# 4. Aggregate to weekly median per product
doe_weekly = (
    doe.groupby(["effectivity_date", "product"])["price_mid"]
    .median()
    .unstack("product")
    .reset_index()
)

# 5. Add week_monday join key
doe_weekly["week_monday"] = doe_weekly["effectivity_date"] - pd.Timedelta(days=1)
doe_weekly = doe_weekly.set_index("week_monday").sort_index()
doe_weekly = doe_weekly.drop(columns=["effectivity_date"])
doe_weekly = doe_weekly.loc["2018-01-01":]

# %%
doe_weekly.to_parquet("../data/semi-cleaned/doe_weekly.parquet")

# %%
doe_weekly.describe()
# Out:
# product      diesel  diesel_plus    kerosene      ron100       ron91  \
# count    373.000000   373.000000  373.000000  346.000000  377.000000
# mean      53.957165    58.765637   64.014162   65.364198   59.069549
# std       15.533749    19.828751   19.656716   10.595172    9.358233
# min       27.430000    29.730000   27.000000   41.580000   37.765000
# 25%       42.250000    44.585000   47.990000   55.600000   52.100000
# 50%       54.995000    59.900000   69.240000   67.056250   58.250000
# 75%       59.950000    65.000000   75.060000   71.713750   64.500000
# max      148.000000   221.815000  161.925000  104.975000   95.125000
#
# product       ron95       ron97
# count    377.000000  377.000000
# mean      60.745305   67.128137
# std        9.621421   26.670986
# min       38.970000   39.822500
# 25%       53.450000   55.370000
# 50%       60.000000   66.820000
# 75%       66.525000   70.875000
# max       99.200000  306.035000

# %%
doe_weekly
# Out:
# product       diesel  diesel_plus  kerosene   ron100    ron91   ron95    ron97
# week_monday
# 2018-02-12    39.175        43.55    48.350      NaN  50.1350  52.070   54.075
# 2018-02-19    38.025        41.98    45.790      NaN  49.0850  50.995   53.020
# 2018-02-26    38.925        43.07    48.935      NaN  49.7350  51.670   53.675
# 2018-03-05    39.175        43.43    49.735      NaN  50.1950  52.170   54.175
# 2018-03-13    38.950        42.88    49.735      NaN  49.9500  51.820   53.825
# ...              ...          ...       ...      ...      ...     ...      ...
# 2026-03-30   131.600       140.00   154.750  102.950  94.5000  98.380  106.900
# 2026-04-06   148.000       155.65   161.925  104.975  95.1250  99.200  107.125
# 2026-04-13   124.400       129.00   155.000   99.500  88.1250  92.025  100.325
# 2026-04-20    99.050       102.15   147.275   92.975  83.7975  86.325   92.400
# 2026-04-27    85.700        88.03   131.640   90.500  82.6000  83.500   91.500
#
# [377 rows x 7 columns]

# %%
doe = pd.read_parquet("../data/semi-cleaned/doe_weekly.parquet")
# effectivity_date was already dropped and week_monday is already the index
# just join directly
master = features.join(doe, how="inner")

import os
os.makedirs("../data/final", exist_ok=True)
master.to_parquet("../data/final/master_weekly.parquet")
print("Saved. Shape:", master.shape)
master.tail()
# Out:
# Saved. Shape: (367, 21)
#              usd_php_close  usd_php_mean  brent_close  brent_mean  wti_close  \
# week_monday
# 2026-03-30       60.206001     59.841000       121.47     111.242     101.26
# 2026-04-06       60.308998     60.456999       127.61     123.935     113.23
# 2026-04-13       59.648998     59.842799       119.07     124.605      98.34
# 2026-04-20       59.988998     59.952801        98.63     114.432      85.91
# 2026-04-27       60.445999     60.025600       111.86     109.618      98.42
#
#              wti_mean  mops_gasoil_close  mops_gasoil_mean  mops_rbob_close  \
# week_monday
# 2026-03-30     94.292         191.488007        189.149402       136.504196
# 2026-04-06    105.670         230.503998        204.551247       138.096004
# 2026-04-13    104.544         194.065994        209.639999       127.566605
# 2026-04-20     93.840         182.509003        191.773001       126.201603
# 2026-04-27     95.430         195.337006        192.018002       145.429200
#
#              mops_rbob_mean  ...  cpi_value  rub_usd_close  rub_usd_mean  \
# week_monday                  ...
# 2026-03-30       130.331038  ...      127.2       0.012289      0.012262
# 2026-04-06       136.953600  ...      127.2       0.012472      0.012380
# 2026-04-13       131.521320  ...      127.2       0.012883      0.012655
# 2026-04-20       129.302881  ...      127.2       0.013094      0.013160
# 2026-04-27       139.517280  ...      127.2       0.013180      0.013279
#
#              diesel  diesel_plus  kerosene   ron100    ron91   ron95    ron97
# week_monday
# 2026-03-30   131.60       140.00   154.750  102.950  94.5000  98.380  106.900
# 2026-04-06   148.00       155.65   161.925  104.975  95.1250  99.200  107.125
# 2026-04-13   124.40       129.00   155.000   99.500  88.1250  92.025  100.325
# 2026-04-20    99.05       102.15   147.275   92.975  83.7975  86.325   92.400
# 2026-04-27    85.70        88.03   131.640   90.500  82.6000  83.500   91.500
#
# [5 rows x 21 columns]
